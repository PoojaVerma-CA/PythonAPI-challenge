# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import requests
from api_keys import w_api_key
from citipy import citipy
import numpy as np
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# check city count to confirm 500
print(len(cities))
# Out:
# 615

# %%
#create weather_df to store city and realted weather attributes
weather_df = pd.DataFrame({'Cities': cities})
weather_df['Country'] = np.NaN
weather_df['Date'] = np.NaN
weather_df['Latitude'] = np.NaN
weather_df['Longitude'] = np.NaN
weather_df['Temperature (F)'] = np.NaN
weather_df['Humidity (%)'] = np.NaN
weather_df['Cloudiness (%)'] = np.NaN
weather_df['Wind Speed (mph)'] = np.NaN
weather_df.head()
# Out:
#      Cities  Country  Date  Latitude  Longitude  Temperature (F)  \
# 0   bijapur      NaN   NaN       NaN        NaN              NaN
# 1  belmonte      NaN   NaN       NaN        NaN              NaN
# 2   ushuaia      NaN   NaN       NaN        NaN              NaN
# 3    kodiak      NaN   NaN       NaN        NaN              NaN
# 4    zaysan      NaN   NaN       NaN        NaN              NaN
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0           NaN             NaN               NaN
# 1           NaN             NaN               NaN
# 2           NaN             NaN               NaN
# 3           NaN             NaN               NaN
# 4           NaN             NaN               NaN

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# api url
url = "http://api.openweathermap.org/data/2.5/weather?"

#set a count for cities
count = 1

# loop through each city to retreive weather data from the api
for city in cities:
    
    # Exception Handling
    try:
        # retreive data for the cities
        print(f"Processing Record {count}, city: {city}")
        query_url = url + "appid=" + w_api_key + "&q=" + city
        response = requests.get(query_url).json()
        
        # write weather data to weather_df                
        weather_df.loc[count-1,'Country'] = response['sys']['country']
        weather_df.loc[count-1,'Date'] = response['dt']
        weather_df.loc[count-1,'Latitude'] = response['coord']['lat']
        weather_df.loc[count-1,'Longitude'] = response['coord']['lon']
        weather_df.loc[count-1,'Temperature (F)'] = response['main']['temp']
        weather_df.loc[count-1,'Humidity (%)'] = response['main']['humidity']
        weather_df.loc[count-1,'Cloudiness (%)'] = response['clouds']['all']
        weather_df.loc[count-1,'Wind Speed (mph)'] = response['wind']['speed']
                
        # Increase Processing Record Counter by 1 for successful processing
        count += 1
    except:
        print(f"Unable to process Record {count}, city: {city} not found. Skipping...")
        
        # Increase Processing Record Counter by 1 when processing is unsucessful
        count += 1
    continue
print(f"-----End of processing-------")
# Out:
# Processing Record 1, city: bijapur
# Processing Record 2, city: belmonte
# Processing Record 3, city: ushuaia
# Processing Record 4, city: kodiak
# Processing Record 5, city: zaysan
# Processing Record 6, city: ilulissat
# Processing Record 7, city: gandajika
# Processing Record 8, city: sadalgi
# Processing Record 9, city: avarua
# Processing Record 10, city: fomboni
# Processing Record 11, city: dudinka
# Processing Record 12, city: juneau
# Processing Record 13, city: east london
# Processing Record 14, city: busselton
# Processing Record 15, city: belaya gora
# Processing Record 16, city: bredasdorp
# Processing Record 17, city: hermanus
# Processing Record 18, city: lolua
# Unable to process Record 18, city: lolua not found. Skipping...
# Processing Record 19, city: new norfolk
# Processing Record 20, city: rikitea
# Processing Record 21, city: russkiy aktash
# Processing Record 22, city: carnarvon
# Processing Record 23, city: jamestown
# Processing Record 24, city: boyolangu
# Processing Record 25, city: dunedin
# Processing Record 26, city: mar del plata
# Processing Record 27, city: dikson
# Processing Record 28, city: bonavista
# Processing Record 29, city: pisco
# Processing Record 30, city: andenes
# Processing Record 31, city: kahului
# Processing Record 32, city: gazli
# Processing Record 33, city: koutsouras
# Processing Record 34, city: punta arenas
# Processing Record 35, city: hambantota
# Processing Record 36, city: atuona
# Processing Record 37, city: grindavik
# Processing Record 38, city: plettenberg bay
# Processing Record 39, city: los llanos de aridane
# Processing Record 40, city: hithadhoo
# Processing Record 41, city: vila franca do campo
# Processing Record 42, city: raciborz
# Processing Record 43, city: mataura
# Processing Record 44, city: port alfred
# Processing Record 45, city: kysyl-syr
# Processing Record 46, city: kaitangata
# Processing Record 47, city: balkanabat
# Processing Record 48, city: pevek
# Processing Record 49, city: albany
# Processing Record 50, city: tasiilaq
# Processing Record 51, city: chokurdakh
# Processing Record 52, city: cognac
# Processing Record 53, city: leningradskiy
# Processing Record 54, city: hobart
# Processing Record 55, city: puerto ayora
# Processing Record 56, city: barentsburg
# Unable to process Record 56, city: barentsburg not found. Skipping...
# Processing Record 57, city: bethel
# Processing Record 58, city: phu ly
# Processing Record 59, city: yellowknife
# Processing Record 60, city: katsuura
# Processing Record 61, city: barrow
# Processing Record 62, city: vaini
# Processing Record 63, city: hilo
# Processing Record 64, city: sao felix do xingu
# Processing Record 65, city: nelson bay
# Processing Record 66, city: sentyabrskiy
# Unable to process Record 66, city: sentyabrskiy not found. Skipping...
# Processing Record 67, city: georgetown
# Processing Record 68, city: rocha
# Processing Record 69, city: kafue
# Processing Record 70, city: saint-philippe
# Processing Record 71, city: kupang
# Processing Record 72, city: nizhneyansk
# Unable to process Record 72, city: nizhneyansk not found. Skipping...
# Processing Record 73, city: hasaki
# Processing Record 74, city: yumen
# Processing Record 75, city: airai
# Processing Record 76, city: visp
# Processing Record 77, city: san cristobal
# Processing Record 78, city: port elizabeth
# Processing Record 79, city: banikoara
# Processing Record 80, city: kapaa
# Processing Record 81, city: thaba-tseka
# Processing Record 82, city: lebu
# Processing Record 83, city: abonnema
# Processing Record 84, city: comodoro rivadavia
# Processing Record 85, city: reyes
# Processing Record 86, city: butaritari
# Processing Record 87, city: avera
# Processing Record 88, city: san quintin
# Processing Record 89, city: geraldton
# Processing Record 90, city: sokoto
# Processing Record 91, city: cidreira
# Processing Record 92, city: bluff
# Processing Record 93, city: lenoir
# Processing Record 94, city: ponta do sol
# Processing Record 95, city: cabra
# Processing Record 96, city: upernavik
# Processing Record 97, city: coquimbo
# Processing Record 98, city: deputatskiy
# Processing Record 99, city: shache
# Processing Record 100, city: fengzhen
# Processing Record 101, city: qafsah
# Unable to process Record 101, city: qafsah not found. Skipping...
# Processing Record 102, city: sozimskiy
# Processing Record 103, city: cape town
# Processing Record 104, city: murgab
# Processing Record 105, city: jalalabad
# Processing Record 106, city: coulihaut
# Unable to process Record 106, city: coulihaut not found. Skipping...
# Processing Record 107, city: juba
# Processing Record 108, city: tumannyy
# Unable to process Record 108, city: tumannyy not found. Skipping...
# Processing Record 109, city: faanui
# Processing Record 110, city: touros
# Processing Record 111, city: nueva gerona
# Processing Record 112, city: namibe
# Processing Record 113, city: illoqqortoormiut
# Unable to process Record 113, city: illoqqortoormiut not found. Skipping...
# Processing Record 114, city: maldonado
# Processing Record 115, city: sorvag
# Unable to process Record 115, city: sorvag not found. Skipping...
# Processing Record 116, city: tuktoyaktuk
# Processing Record 117, city: bathsheba
# Processing Record 118, city: alofi
# Processing Record 119, city: qaanaaq
# Processing Record 120, city: tilichiki
# Processing Record 121, city: vao
# Processing Record 122, city: esperance
# Processing Record 123, city: ahipara
# Processing Record 124, city: half moon bay
# Processing Record 125, city: banjar
# Processing Record 126, city: victoria
# Processing Record 127, city: kodinsk
# Processing Record 128, city: luwuk
# Processing Record 129, city: presidencia roque saenz pena
# Processing Record 130, city: norman wells
# Processing Record 131, city: bay roberts
# Processing Record 132, city: rio grande
# Processing Record 133, city: narsaq
# Processing Record 134, city: padang
# Processing Record 135, city: caborca
# Processing Record 136, city: sioux lookout
# Processing Record 137, city: mount isa
# Processing Record 138, city: taolanaro
# Unable to process Record 138, city: taolanaro not found. Skipping...
# Processing Record 139, city: nosivka
# Processing Record 140, city: attawapiskat
# Unable to process Record 140, city: attawapiskat not found. Skipping...
# Processing Record 141, city: yakeshi
# Processing Record 142, city: novyy yegorlyk
# Processing Record 143, city: belushya guba
# Unable to process Record 143, city: belushya guba not found. Skipping...
# Processing Record 144, city: skjervoy
# Processing Record 145, city: castro
# Processing Record 146, city: ust-kulom
# Processing Record 147, city: vostok
# Processing Record 148, city: almenara
# Processing Record 149, city: pangkalanbuun
# Processing Record 150, city: leh
# Processing Record 151, city: amderma
# Unable to process Record 151, city: amderma not found. Skipping...
# Processing Record 152, city: fortaleza
# Processing Record 153, city: iqaluit
# Processing Record 154, city: tuatapere
# Processing Record 155, city: palabuhanratu
# Unable to process Record 155, city: palabuhanratu not found. Skipping...
# Processing Record 156, city: chuy
# Processing Record 157, city: bereda
# Processing Record 158, city: mende
# Processing Record 159, city: kavieng
# Processing Record 160, city: talnakh
# Processing Record 161, city: lata
# Processing Record 162, city: san patricio
# Processing Record 163, city: labe
# Processing Record 164, city: chilca
# Processing Record 165, city: nikolskoye
# Processing Record 166, city: laguna
# Processing Record 167, city: lac-megantic
# Processing Record 168, city: springville
# Processing Record 169, city: kavaratti
# Processing Record 170, city: westport
# Processing Record 171, city: barawe
# Unable to process Record 171, city: barawe not found. Skipping...
# Processing Record 172, city: yar-sale
# Processing Record 173, city: montepuez
# Processing Record 174, city: dawlatabad
# Processing Record 175, city: freeport
# Processing Record 176, city: thompson
# Processing Record 177, city: shenzhen
# Processing Record 178, city: mokolo
# Processing Record 179, city: mys shmidta
# Unable to process Record 179, city: mys shmidta not found. Skipping...
# Processing Record 180, city: kruisfontein
# Processing Record 181, city: palmer
# Processing Record 182, city: sistranda
# Processing Record 183, city: slave lake
# Processing Record 184, city: severo-kurilsk
# Processing Record 185, city: winfield
# Processing Record 186, city: khatanga
# Processing Record 187, city: urumqi
# Processing Record 188, city: goundi
# Processing Record 189, city: pombas
# Processing Record 190, city: liwale
# Processing Record 191, city: mamlyutka
# Processing Record 192, city: codrington
# Processing Record 193, city: najran
# Processing Record 194, city: toftir
# Unable to process Record 194, city: toftir not found. Skipping...
# Processing Record 195, city: shimoda
# Processing Record 196, city: banon
# Processing Record 197, city: port keats
# Processing Record 198, city: kyaikkami
# Processing Record 199, city: constitucion
# Processing Record 200, city: praia
# Processing Record 201, city: matagami
# Processing Record 202, city: edd
# Processing Record 203, city: aklavik
# Processing Record 204, city: pyrzyce
# Processing Record 205, city: sal rei
# Processing Record 206, city: ladario
# Processing Record 207, city: tessalit
# Processing Record 208, city: vanavara
# Processing Record 209, city: martapura
# Processing Record 210, city: bambous virieux
# Processing Record 211, city: mocambique
# Unable to process Record 211, city: mocambique not found. Skipping...
# Processing Record 212, city: sabha
# Processing Record 213, city: socorro
# Processing Record 214, city: stykkisholmur
# Processing Record 215, city: samusu
# Unable to process Record 215, city: samusu not found. Skipping...
# Processing Record 216, city: cabo san lucas
# Processing Record 217, city: andevoranto
# Unable to process Record 217, city: andevoranto not found. Skipping...
# Processing Record 218, city: dzheyrakh
# Processing Record 219, city: saskylakh
# Processing Record 220, city: quatre cocos
# Processing Record 221, city: miri
# Processing Record 222, city: turukhansk
# Processing Record 223, city: souillac
# Processing Record 224, city: labutta
# Unable to process Record 224, city: labutta not found. Skipping...
# Processing Record 225, city: sitka
# Processing Record 226, city: dianopolis
# Unable to process Record 226, city: dianopolis not found. Skipping...
# Processing Record 227, city: sindor
# Processing Record 228, city: antsohihy
# Processing Record 229, city: ereymentau
# Processing Record 230, city: taoudenni
# Processing Record 231, city: savannah bight
# Processing Record 232, city: tiksi
# Processing Record 233, city: port blair
# Processing Record 234, city: kazalinsk
# Unable to process Record 234, city: kazalinsk not found. Skipping...
# Processing Record 235, city: mariinsk
# Processing Record 236, city: verkhnyaya inta
# Processing Record 237, city: maniitsoq
# Processing Record 238, city: buj
# Processing Record 239, city: strezhevoy
# Processing Record 240, city: lompoc
# Processing Record 241, city: tankara
# Processing Record 242, city: labuhan
# Processing Record 243, city: lavrentiya
# Processing Record 244, city: torbay
# Processing Record 245, city: saint george
# Processing Record 246, city: moussoro
# Processing Record 247, city: temaraia
# Unable to process Record 247, city: temaraia not found. Skipping...
# Processing Record 248, city: omboue
# Processing Record 249, city: arraial do cabo
# Processing Record 250, city: lufilufi
# Processing Record 251, city: mahebourg
# Processing Record 252, city: key largo
# Processing Record 253, city: port lincoln
# Processing Record 254, city: la tuque
# Processing Record 255, city: seydi
# Processing Record 256, city: vestmannaeyjar
# Processing Record 257, city: mao
# Processing Record 258, city: jiangyou
# Processing Record 259, city: cherskiy
# Processing Record 260, city: mazamari
# Processing Record 261, city: ahuimanu
# Processing Record 262, city: hwange
# Processing Record 263, city: ketchikan
# Processing Record 264, city: ribeira grande
# Processing Record 265, city: tela
# Processing Record 266, city: chinsali
# Processing Record 267, city: sigli
# Processing Record 268, city: durazno
# Processing Record 269, city: garowe
# Processing Record 270, city: umm lajj
# Processing Record 271, city: dimbokro
# Processing Record 272, city: christchurch
# Processing Record 273, city: dzhusaly
# Unable to process Record 273, city: dzhusaly not found. Skipping...
# Processing Record 274, city: vardo
# Processing Record 275, city: jiayuguan
# Processing Record 276, city: dutse
# Processing Record 277, city: hervey bay
# Processing Record 278, city: cam ranh
# Processing Record 279, city: te anau
# Processing Record 280, city: san jose
# Processing Record 281, city: grand river south east
# Unable to process Record 281, city: grand river south east not found. Skipping...
# Processing Record 282, city: arteaga
# Processing Record 283, city: renqiu
# Processing Record 284, city: bria
# Processing Record 285, city: poso
# Processing Record 286, city: mount gambier
# Processing Record 287, city: colac
# Processing Record 288, city: deniliquin
# Processing Record 289, city: salmo
# Processing Record 290, city: nioro
# Processing Record 291, city: vila do maio
# Processing Record 292, city: saint-augustin
# Processing Record 293, city: satinka
# Processing Record 294, city: provideniya
# Processing Record 295, city: bath
# Processing Record 296, city: rawannawi
# Unable to process Record 296, city: rawannawi not found. Skipping...
# Processing Record 297, city: raton
# Processing Record 298, city: beringovskiy
# Processing Record 299, city: esna
# Processing Record 300, city: zelenoborskiy
# Processing Record 301, city: willowmore
# Processing Record 302, city: moniquira
# Processing Record 303, city: sertania
# Processing Record 304, city: texarkana
# Processing Record 305, city: bama
# Processing Record 306, city: turkmenabat
# Processing Record 307, city: rodrigues alves
# Processing Record 308, city: kiunga
# Processing Record 309, city: wakkanai
# Processing Record 310, city: cadillac
# Processing Record 311, city: yanam
# Processing Record 312, city: ankara
# Processing Record 313, city: nome
# Processing Record 314, city: kailua
# Processing Record 315, city: thinadhoo
# Processing Record 316, city: patiya
# Processing Record 317, city: bam
# Processing Record 318, city: horizontina
# Processing Record 319, city: longyearbyen
# Processing Record 320, city: kieta
# Processing Record 321, city: turayf
# Processing Record 322, city: skelleftea
# Processing Record 323, city: vaitupu
# Unable to process Record 323, city: vaitupu not found. Skipping...
# Processing Record 324, city: chapais
# Processing Record 325, city: ingham
# Processing Record 326, city: lorengau
# Processing Record 327, city: verkhnevilyuysk
# Processing Record 328, city: piacabucu
# Processing Record 329, city: dickinson
# Processing Record 330, city: oussouye
# Processing Record 331, city: khonuu
# Unable to process Record 331, city: khonuu not found. Skipping...
# Processing Record 332, city: skalistyy
# Unable to process Record 332, city: skalistyy not found. Skipping...
# Processing Record 333, city: boa vista
# Processing Record 334, city: nanortalik
# Processing Record 335, city: ituango
# Processing Record 336, city: umzimvubu
# Unable to process Record 336, city: umzimvubu not found. Skipping...
# Processing Record 337, city: poum
# Processing Record 338, city: dabhol
# Processing Record 339, city: komsomolskiy
# Processing Record 340, city: isangel
# Processing Record 341, city: nemuro
# Processing Record 342, city: svetlaya
# Processing Record 343, city: fairbanks
# Processing Record 344, city: iisalmi
# Processing Record 345, city: kaili
# Processing Record 346, city: mana
# Processing Record 347, city: brigantine
# Processing Record 348, city: rincon
# Processing Record 349, city: the valley
# Processing Record 350, city: goderich
# Processing Record 351, city: antalaha
# Processing Record 352, city: samarkand
# Processing Record 353, city: neustrelitz
# Processing Record 354, city: luderitz
# Processing Record 355, city: bengkulu
# Processing Record 356, city: loksa
# Processing Record 357, city: pangnirtung
# Processing Record 358, city: rorvik
# Processing Record 359, city: xihua
# Processing Record 360, city: slyudyanka
# Processing Record 361, city: caucaia
# Processing Record 362, city: otane
# Processing Record 363, city: fredericia
# Processing Record 364, city: san luis
# Processing Record 365, city: vila
# Processing Record 366, city: moerai
# Processing Record 367, city: araouane
# Processing Record 368, city: znamenskoye
# Processing Record 369, city: tabas
# Processing Record 370, city: grigoropolisskaya
# Processing Record 371, city: manakara
# Processing Record 372, city: vysoke myto
# Processing Record 373, city: sidney
# Processing Record 374, city: ye
# Unable to process Record 374, city: ye not found. Skipping...
# Processing Record 375, city: wanning
# Processing Record 376, city: homer
# Processing Record 377, city: ranong
# Processing Record 378, city: aviles
# Processing Record 379, city: bambanglipuro
# Processing Record 380, city: saryshagan
# Unable to process Record 380, city: saryshagan not found. Skipping...
# Processing Record 381, city: horsham
# Processing Record 382, city: college
# Processing Record 383, city: paamiut
# Processing Record 384, city: calabar
# Processing Record 385, city: ouadda
# Processing Record 386, city: bengbu
# Processing Record 387, city: naze
# Processing Record 388, city: tefe
# Processing Record 389, city: quang ngai
# Processing Record 390, city: sola
# Processing Record 391, city: keflavik
# Processing Record 392, city: saleaula
# Unable to process Record 392, city: saleaula not found. Skipping...
# Processing Record 393, city: boden
# Processing Record 394, city: tura
# Processing Record 395, city: bilma
# Processing Record 396, city: ayolas
# Processing Record 397, city: neiafu
# Processing Record 398, city: adrar
# Processing Record 399, city: husavik
# Processing Record 400, city: fortuna
# Processing Record 401, city: bilibino
# Processing Record 402, city: lakes entrance
# Processing Record 403, city: luganville
# Processing Record 404, city: oum hadjer
# Processing Record 405, city: chillicothe
# Processing Record 406, city: lagoa
# Processing Record 407, city: ennis
# Processing Record 408, city: jiroft
# Unable to process Record 408, city: jiroft not found. Skipping...
# Processing Record 409, city: uruzgan
# Processing Record 410, city: hobyo
# Processing Record 411, city: muros
# Processing Record 412, city: benghazi
# Processing Record 413, city: adelaide
# Processing Record 414, city: maningrida
# Processing Record 415, city: champerico
# Processing Record 416, city: imeni stepana razina
# Processing Record 417, city: ostrovnoy
# Processing Record 418, city: peniche
# Processing Record 419, city: henties bay
# Processing Record 420, city: rio gallegos
# Processing Record 421, city: iracoubo
# Processing Record 422, city: labuan
# Processing Record 423, city: takoradi
# Processing Record 424, city: uthal
# Processing Record 425, city: rudnogorsk
# Processing Record 426, city: teknaf
# Processing Record 427, city: miles city
# Processing Record 428, city: svirstroy
# Processing Record 429, city: samarai
# Processing Record 430, city: upata
# Processing Record 431, city: makakilo city
# Processing Record 432, city: guerrero negro
# Processing Record 433, city: yelkhovka
# Processing Record 434, city: yerbogachen
# Processing Record 435, city: yangambi
# Processing Record 436, city: rongcheng
# Processing Record 437, city: phangnga
# Processing Record 438, city: flinders
# Processing Record 439, city: birao
# Processing Record 440, city: tawzar
# Unable to process Record 440, city: tawzar not found. Skipping...
# Processing Record 441, city: kato mazarakion
# Processing Record 442, city: margate
# Processing Record 443, city: lasa
# Processing Record 444, city: hun
# Processing Record 445, city: ajdabiya
# Processing Record 446, city: tamasopo
# Processing Record 447, city: hamilton
# Processing Record 448, city: kamenskoye
# Unable to process Record 448, city: kamenskoye not found. Skipping...
# Processing Record 449, city: abu dhabi
# Processing Record 450, city: arlit
# Processing Record 451, city: coihaique
# Processing Record 452, city: ulfborg
# Processing Record 453, city: tambul
# Unable to process Record 453, city: tambul not found. Skipping...
# Processing Record 454, city: marsh harbour
# Processing Record 455, city: lakatoro
# Processing Record 456, city: nampula
# Processing Record 457, city: roald
# Processing Record 458, city: honiara
# Processing Record 459, city: novonikolayevskaya
# Processing Record 460, city: rovaniemi
# Processing Record 461, city: ostersund
# Processing Record 462, city: ponta delgada
# Processing Record 463, city: tabuk
# Processing Record 464, city: kogon
# Processing Record 465, city: tsihombe
# Unable to process Record 465, city: tsihombe not found. Skipping...
# Processing Record 466, city: san policarpo
# Processing Record 467, city: zabid
# Processing Record 468, city: olinda
# Processing Record 469, city: sampit
# Processing Record 470, city: oistins
# Processing Record 471, city: rawlins
# Processing Record 472, city: corcoran
# Processing Record 473, city: llanes
# Processing Record 474, city: wajir
# Processing Record 475, city: cap-aux-meules
# Processing Record 476, city: shingu
# Processing Record 477, city: cockburn town
# Processing Record 478, city: cusuna
# Processing Record 479, city: riaba
# Unable to process Record 479, city: riaba not found. Skipping...
# Processing Record 480, city: sorland
# Processing Record 481, city: nguiu
# Unable to process Record 481, city: nguiu not found. Skipping...
# Processing Record 482, city: katakwi
# Processing Record 483, city: broken hill
# Processing Record 484, city: mangrol
# Processing Record 485, city: gulu
# Processing Record 486, city: turka
# Processing Record 487, city: baykit
# Processing Record 488, city: buraydah
# Processing Record 489, city: sao joao da barra
# Processing Record 490, city: saiha
# Processing Record 491, city: gravdal
# Processing Record 492, city: almaznyy
# Processing Record 493, city: warqla
# Unable to process Record 493, city: warqla not found. Skipping...
# Processing Record 494, city: daxian
# Unable to process Record 494, city: daxian not found. Skipping...
# Processing Record 495, city: la palma
# Processing Record 496, city: balasheyka
# Processing Record 497, city: placido de castro
# Processing Record 498, city: port hardy
# Processing Record 499, city: zhigansk
# Processing Record 500, city: klaksvik
# Processing Record 501, city: jalu
# Processing Record 502, city: nyurba
# Processing Record 503, city: malwan
# Unable to process Record 503, city: malwan not found. Skipping...
# Processing Record 504, city: eganville
# Processing Record 505, city: awjilah
# Processing Record 506, city: salalah
# Processing Record 507, city: collie
# Processing Record 508, city: stornoway
# Processing Record 509, city: ornskoldsvik
# Processing Record 510, city: koslan
# Processing Record 511, city: ewa beach
# Processing Record 512, city: cururupu
# Processing Record 513, city: honningsvag
# Processing Record 514, city: ipora
# Processing Record 515, city: beidao
# Processing Record 516, city: buariki
# Unable to process Record 516, city: buariki not found. Skipping...
# Processing Record 517, city: harper
# Processing Record 518, city: romitan
# Processing Record 519, city: varhaug
# Processing Record 520, city: mae tha
# Processing Record 521, city: nukus
# Processing Record 522, city: srednekolymsk
# Processing Record 523, city: itarema
# Processing Record 524, city: apolda
# Processing Record 525, city: beit jann
# Processing Record 526, city: zolotinka
# Unable to process Record 526, city: zolotinka not found. Skipping...
# Processing Record 527, city: codajas
# Processing Record 528, city: kirakira
# Processing Record 529, city: gazanjyk
# Processing Record 530, city: mezen
# Processing Record 531, city: muroto
# Processing Record 532, city: traverse city
# Processing Record 533, city: sibolga
# Processing Record 534, city: abeche
# Processing Record 535, city: berlevag
# Processing Record 536, city: ellisras
# Processing Record 537, city: mayo
# Processing Record 538, city: nha trang
# Processing Record 539, city: miramar
# Processing Record 540, city: ballina
# Processing Record 541, city: waingapu
# Processing Record 542, city: caronport
# Processing Record 543, city: biak
# Processing Record 544, city: katobu
# Processing Record 545, city: temba
# Processing Record 546, city: ossora
# Processing Record 547, city: turbat
# Processing Record 548, city: javanrud
# Processing Record 549, city: asyut
# Processing Record 550, city: nova olinda do norte
# Processing Record 551, city: ayan
# Processing Record 552, city: san-pedro
# Processing Record 553, city: faro
# Processing Record 554, city: sankt andra
# Unable to process Record 554, city: sankt andra not found. Skipping...
# Processing Record 555, city: clyde river
# Processing Record 556, city: shinpokh
# Processing Record 557, city: ust-nera
# Processing Record 558, city: kenai
# Processing Record 559, city: lucapa
# Processing Record 560, city: singarayakonda
# Processing Record 561, city: tunduru
# Unable to process Record 561, city: tunduru not found. Skipping...
# Processing Record 562, city: kendari
# Processing Record 563, city: lazaro cardenas
# Processing Record 564, city: marfino
# Processing Record 565, city: galle
# Processing Record 566, city: paramirim
# Processing Record 567, city: kargopol
# Processing Record 568, city: usinsk
# Processing Record 569, city: dawei
# Processing Record 570, city: mastic beach
# Processing Record 571, city: inuvik
# Processing Record 572, city: iralaya
# Processing Record 573, city: tabou
# Processing Record 574, city: daraitan
# Processing Record 575, city: nadym
# Processing Record 576, city: marsa matruh
# Processing Record 577, city: hualmay
# Processing Record 578, city: gudalur
# Processing Record 579, city: kismayo
# Processing Record 580, city: malinovoye ozero
# Processing Record 581, city: pitimbu
# Processing Record 582, city: broome
# Processing Record 583, city: xinqing
# Processing Record 584, city: alice springs
# Processing Record 585, city: blyth
# Processing Record 586, city: khasan
# Processing Record 587, city: wanxian
# Processing Record 588, city: butzbach
# Processing Record 589, city: aldergrove
# Processing Record 590, city: viligili
# Unable to process Record 590, city: viligili not found. Skipping...
# Processing Record 591, city: potgietersrus
# Unable to process Record 591, city: potgietersrus not found. Skipping...
# Processing Record 592, city: shubarshi
# Processing Record 593, city: truro
# Processing Record 594, city: sulangan
# Processing Record 595, city: afyonkarahisar
# Processing Record 596, city: bradford
# Processing Record 597, city: gouyave
# Processing Record 598, city: joshimath
# Processing Record 599, city: agadir
# Processing Record 600, city: petrovskoye
# Processing Record 601, city: kota
# Processing Record 602, city: caravelas
# Processing Record 603, city: yulara
# Processing Record 604, city: ancud
# Processing Record 605, city: mahibadhoo
# Processing Record 606, city: suntar
# Processing Record 607, city: garden city
# Processing Record 608, city: nabire
# Processing Record 609, city: lillooet
# Processing Record 610, city: middelharnis
# Processing Record 611, city: yicheng
# Processing Record 612, city: ola
# Processing Record 613, city: saint-georges
# Processing Record 614, city: lethem
# Processing Record 615, city: port shepstone
# -----End of processing-------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# drop the records with NaN values
weather_df.dropna(inplace=True)

# write weather_df to the csv file
weather_df.to_csv('output_data/cities.csv')
weather_df
# Out:
#            Cities Country          Date  Latitude  Longitude  Temperature (F)  \
# 0            buin      CL  1.601702e+09    -33.73     -70.75           281.62
# 1    constitucion      CL  1.601702e+09    -35.33     -72.42           280.54
# 2       ulladulla      AU  1.601702e+09    -35.35     150.47           301.44
# 3      whitecourt      CA  1.601702e+09     54.15    -115.69           283.15
# 4          barrow      US  1.601702e+09     71.29    -156.79           275.15
# ..            ...     ...           ...       ...        ...              ...
# 639         yumen      CN  1.601702e+09     40.28      97.20           286.43
# 640     ugoofaaru      MV  1.601702e+09      5.67      73.00           301.24
# 642     nang rong      TH  1.601702e+09     14.64     102.79           302.70
# 643       paamiut      GL  1.601702e+09     61.99     -49.67           275.79
# 644        gashua      NG  1.601702e+09     12.87      11.05           300.02
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0            80.0            11.0              2.60
# 1            75.0             3.0              4.15
# 2            23.0             0.0              6.20
# 3            68.0            20.0              0.74
# 4            95.0            90.0              8.70
# ..            ...             ...               ...
# 639          29.0             0.0              7.91
# 640          72.0            95.0              5.52
# 642          83.0            75.0              1.50
# 643          88.0           100.0              3.40
# 644          60.0            47.0              3.90
#
# [592 rows x 9 columns]

# %%
# get statistical summary for weather_df
weather_df.describe()
# Out:
#                Date    Latitude   Longitude  Temperature (F)  Humidity (%)  \
# count  5.650000e+02  565.000000  565.000000       565.000000    565.000000
# mean   1.601709e+09   21.890496   18.512690       291.145097     69.759292
# std    9.074874e+01   33.001155   89.008485         9.818666     21.942351
# min    1.601709e+09  -54.800000 -175.200000       266.900000      1.000000
# 25%    1.601709e+09   -3.740000  -56.900000       283.150000     61.000000
# 50%    1.601709e+09   25.990000   22.400000       292.040000     74.000000
# 75%    1.601709e+09   49.280000   92.970000       299.210000     86.000000
# max    1.601709e+09   78.220000  179.320000       312.880000    100.000000
#
#        Cloudiness (%)  Wind Speed (mph)
# count      565.000000        565.000000
# mean        51.336283          3.913504
# std         41.281169          2.642240
# min          0.000000          0.230000
# 25%          1.000000          1.810000
# 50%         61.000000          3.550000
# 75%         96.000000          5.300000
# max        100.000000         14.900000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# No Cities with humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Temperature (F)'], facecolors='red', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Temperature.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: Temperatures generally increase as the cities get closer to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Humidity (%)'], facecolors='blue', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Humidity')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Humidity.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: The charts do not demonstrate correlation between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness (%)'], facecolors='yellow', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Cloudiness.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: The charts do not demonstrate correlation between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed (mph)'], facecolors='green', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Wind Speed.png')

# Show Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# OBSERVATION: The wind speeds are higher further from the equator.

# %% [markdown]
# ## Linear Regression

# %%
#get data for northern and southern hemisphere
north_df = weather_df.loc[weather_df['Latitude'] > 0]
south_df = weather_df.loc[weather_df['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Temperature (F)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='red', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"b-")


# Define Graph Attributes
plt.annotate(line_eq,(0,270),fontsize=15,color='blue')
plt.title('Northern Hemisphere City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: -0.8450231027499246

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Temperature (F)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='red', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"b-")


# Define Graph Attributes
plt.annotate(line_eq,(-30,275),fontsize=15,color='blue')
plt.title('Southern Hemisphere City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.7241910196116674

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Humidity (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='blue', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(45,10),fontsize=15,color='red')
plt.title('Northern Hemisphere City Latitude vs. Humidity')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.18083967275089996

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Humidity (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='blue', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(-55,5),fontsize=15,color='red')
plt.title('Southern Hemisphere City Latitude vs. Humidity')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.020430313125072402

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Cloudiness (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='yellow', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"g-")


# Define Graph Attributes
plt.annotate(line_eq,(10,60),fontsize=15,color='green')
plt.title('Northern Hemisphere City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.06697805044676257

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Cloudiness (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='yellow', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"g-")


# Define Graph Attributes
plt.annotate(line_eq,(0,10),fontsize=15,color='green')
plt.title('Southern Hemisphere City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: -0.08975101006409204

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Wind Speed (mph)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='green', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(10,10),fontsize=15,color='red')
plt.title('Northern Hemisphere City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.1652990841013456

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Wind Speed (mph)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='green', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(-55,11),fontsize=15,color='red')
plt.title('Southern Hemisphere City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: -0.2072854846255869
