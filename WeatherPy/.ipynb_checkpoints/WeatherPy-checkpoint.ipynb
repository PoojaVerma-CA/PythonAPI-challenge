# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import requests
from api_keys import w_api_key
from citipy import citipy
import gmaps
import numpy as np
import pandas as pd
from scipy.stats import linregress
from matplotlib import pyplot as plt

# Output File (CSV)
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)
print(w_api_key)
# Out:
# 0a6046beeda0191eb61e48712f49cfb7

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:

    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# check city count to confirm 500

print(len(cities))
# Out:
# 645

# %%
weather_df = pd.DataFrame({'Cities': cities})
weather_df['Country'] = np.NaN
weather_df['Date'] = np.NaN
weather_df['Latitude'] = np.NaN
weather_df['Longitude'] = np.NaN
weather_df['Temperature (F)'] = np.NaN
weather_df['Humidity (%)'] = np.NaN
weather_df['Cloudiness (%)'] = np.NaN
weather_df['Wind Speed (mph)'] = np.NaN
weather_df.head()
# Out:
#          Cities  Country  Date  Latitude  Longitude  Temperature (F)  \
# 0          buin      NaN   NaN       NaN        NaN              NaN
# 1  constitucion      NaN   NaN       NaN        NaN              NaN
# 2     ulladulla      NaN   NaN       NaN        NaN              NaN
# 3    whitecourt      NaN   NaN       NaN        NaN              NaN
# 4        barrow      NaN   NaN       NaN        NaN              NaN
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0           NaN             NaN               NaN
# 1           NaN             NaN               NaN
# 2           NaN             NaN               NaN
# 3           NaN             NaN               NaN
# 4           NaN             NaN               NaN

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
count = 1

# Build query URL

#retreive data for the cities
for city in cities:
    # Exception Handling
    try:
        print(f"Processing Record {count}, city: {city}")
        query_url = url + "appid=" + w_api_key + "&q=" + city
        response = requests.get(query_url).json()
                
        weather_df.loc[count-1,'Country'] = response['sys']['country']
        weather_df.loc[count-1,'Date'] = response['dt']
        weather_df.loc[count-1,'Latitude'] = response['coord']['lat']
        weather_df.loc[count-1,'Longitude'] = response['coord']['lon']
        weather_df.loc[count-1,'Temperature (F)'] = response['main']['temp']
        weather_df.loc[count-1,'Humidity (%)'] = response['main']['humidity']
        weather_df.loc[count-1,'Cloudiness (%)'] = response['clouds']['all']
        weather_df.loc[count-1,'Wind Speed (mph)'] = response['wind']['speed']
        
        
        # Increase Processing Record Counter by 1 For Each Loop
        count += 1
    except:
        print(f"Unable to process Record {count}, city: {city} not found. Skipping...")
        count += 1
    continue
print(f"-----End of processing-------")
# Out:
# Processing Record 1, city: buin
# Processing Record 2, city: constitucion
# Processing Record 3, city: ulladulla
# Processing Record 4, city: whitecourt
# Processing Record 5, city: barrow
# Processing Record 6, city: jamestown
# Processing Record 7, city: spitak
# Processing Record 8, city: saskylakh
# Processing Record 9, city: flinders
# Processing Record 10, city: makakilo city
# Processing Record 11, city: bethel
# Processing Record 12, city: rawson
# Processing Record 13, city: half moon bay
# Processing Record 14, city: hithadhoo
# Processing Record 15, city: saint-philippe
# Processing Record 16, city: bud
# Processing Record 17, city: busselton
# Processing Record 18, city: gamba
# Processing Record 19, city: vaitupu
# Unable to process Record 19, city: vaitupu not found. Skipping...
# Processing Record 20, city: taolanaro
# Unable to process Record 20, city: taolanaro not found. Skipping...
# Processing Record 21, city: peno
# Processing Record 22, city: tautira
# Processing Record 23, city: srbobran
# Processing Record 24, city: pangnirtung
# Processing Record 25, city: albany
# Processing Record 26, city: ritchie
# Processing Record 27, city: ribeira grande
# Processing Record 28, city: atuona
# Processing Record 29, city: faya
# Processing Record 30, city: barentsburg
# Unable to process Record 30, city: barentsburg not found. Skipping...
# Processing Record 31, city: jalu
# Processing Record 32, city: shirokiy
# Processing Record 33, city: labrea
# Processing Record 34, city: east london
# Processing Record 35, city: thompson
# Processing Record 36, city: ushuaia
# Processing Record 37, city: castro
# Processing Record 38, city: samalaeulu
# Unable to process Record 38, city: samalaeulu not found. Skipping...
# Processing Record 39, city: sulina
# Processing Record 40, city: hobart
# Processing Record 41, city: izmit
# Processing Record 42, city: rikitea
# Processing Record 43, city: esperance
# Processing Record 44, city: san patricio
# Processing Record 45, city: bluff
# Processing Record 46, city: hasaki
# Processing Record 47, city: kodiak
# Processing Record 48, city: ngerengere
# Processing Record 49, city: punta arenas
# Processing Record 50, city: vila velha
# Processing Record 51, city: souillac
# Processing Record 52, city: chiredzi
# Processing Record 53, city: indramayu
# Processing Record 54, city: iqaluit
# Processing Record 55, city: yaan
# Processing Record 56, city: port alfred
# Processing Record 57, city: kapaa
# Processing Record 58, city: arraial do cabo
# Processing Record 59, city: aklavik
# Processing Record 60, city: mys shmidta
# Unable to process Record 60, city: mys shmidta not found. Skipping...
# Processing Record 61, city: yeppoon
# Processing Record 62, city: nema
# Processing Record 63, city: honningsvag
# Processing Record 64, city: belushya guba
# Unable to process Record 64, city: belushya guba not found. Skipping...
# Processing Record 65, city: amderma
# Unable to process Record 65, city: amderma not found. Skipping...
# Processing Record 66, city: jinchang
# Processing Record 67, city: chokurdakh
# Processing Record 68, city: ejura
# Processing Record 69, city: mahebourg
# Processing Record 70, city: clyde river
# Processing Record 71, city: saint george
# Processing Record 72, city: tuatapere
# Processing Record 73, city: port lincoln
# Processing Record 74, city: cape town
# Processing Record 75, city: morondava
# Processing Record 76, city: avarua
# Processing Record 77, city: toliary
# Unable to process Record 77, city: toliary not found. Skipping...
# Processing Record 78, city: nikolskoye
# Processing Record 79, city: victoria
# Processing Record 80, city: illoqqortoormiut
# Unable to process Record 80, city: illoqqortoormiut not found. Skipping...
# Processing Record 81, city: sampit
# Processing Record 82, city: kogon
# Processing Record 83, city: vaini
# Processing Record 84, city: alofi
# Processing Record 85, city: hirara
# Processing Record 86, city: xuddur
# Processing Record 87, city: marsa matruh
# Processing Record 88, city: carolina
# Processing Record 89, city: najran
# Processing Record 90, city: sioux lookout
# Processing Record 91, city: mataura
# Processing Record 92, city: severo-kurilsk
# Processing Record 93, city: bajo baudo
# Unable to process Record 93, city: bajo baudo not found. Skipping...
# Processing Record 94, city: kamalpur
# Processing Record 95, city: cayenne
# Processing Record 96, city: tuktoyaktuk
# Processing Record 97, city: provideniya
# Processing Record 98, city: college
# Processing Record 99, city: north bend
# Processing Record 100, city: basco
# Processing Record 101, city: saldanha
# Processing Record 102, city: huanren
# Processing Record 103, city: opunake
# Processing Record 104, city: henties bay
# Processing Record 105, city: grindavik
# Processing Record 106, city: tiksi
# Processing Record 107, city: kursk
# Processing Record 108, city: saleaula
# Unable to process Record 108, city: saleaula not found. Skipping...
# Processing Record 109, city: rio grande
# Processing Record 110, city: yellowknife
# Processing Record 111, city: kirakira
# Processing Record 112, city: ponta do sol
# Processing Record 113, city: moron
# Processing Record 114, city: makaryev
# Processing Record 115, city: cabo san lucas
# Processing Record 116, city: lompoc
# Processing Record 117, city: camocim
# Processing Record 118, city: aleksandrov gay
# Processing Record 119, city: hilo
# Processing Record 120, city: lufilufi
# Processing Record 121, city: rawannawi
# Unable to process Record 121, city: rawannawi not found. Skipping...
# Processing Record 122, city: georgetown
# Processing Record 123, city: manggar
# Processing Record 124, city: new norfolk
# Processing Record 125, city: kichmengskiy gorodok
# Processing Record 126, city: cidreira
# Processing Record 127, city: upernavik
# Processing Record 128, city: yulara
# Processing Record 129, city: ijaki
# Unable to process Record 129, city: ijaki not found. Skipping...
# Processing Record 130, city: gwadar
# Processing Record 131, city: lebu
# Processing Record 132, city: sergeyevka
# Processing Record 133, city: fortuna
# Processing Record 134, city: sola
# Processing Record 135, city: vanavara
# Processing Record 136, city: kamen-rybolov
# Processing Record 137, city: zhigansk
# Processing Record 138, city: gold coast
# Processing Record 139, city: naze
# Processing Record 140, city: gizo
# Processing Record 141, city: kimberley
# Processing Record 142, city: nizhneyansk
# Unable to process Record 142, city: nizhneyansk not found. Skipping...
# Processing Record 143, city: butaritari
# Processing Record 144, city: lewistown
# Processing Record 145, city: hurricane
# Processing Record 146, city: boueni
# Processing Record 147, city: dhidhdhoo
# Processing Record 148, city: griffith
# Processing Record 149, city: marzuq
# Processing Record 150, city: pudozh
# Processing Record 151, city: puerto ayora
# Processing Record 152, city: haines junction
# Processing Record 153, city: san quintin
# Processing Record 154, city: svetlogorsk
# Processing Record 155, city: sao felix do xingu
# Processing Record 156, city: grand gaube
# Processing Record 157, city: izvestkovyy
# Processing Record 158, city: chuy
# Processing Record 159, city: si satchanalai
# Processing Record 160, city: narsaq
# Processing Record 161, city: airai
# Processing Record 162, city: pangody
# Processing Record 163, city: kavaratti
# Processing Record 164, city: kaitangata
# Processing Record 165, city: poum
# Processing Record 166, city: bar harbor
# Processing Record 167, city: bengkulu
# Processing Record 168, city: hermanus
# Processing Record 169, city: marcona
# Unable to process Record 169, city: marcona not found. Skipping...
# Processing Record 170, city: nanortalik
# Processing Record 171, city: troitsko-pechorsk
# Processing Record 172, city: phan thiet
# Processing Record 173, city: kavieng
# Processing Record 174, city: culebra
# Processing Record 175, city: edea
# Processing Record 176, city: cherskiy
# Processing Record 177, city: dhemaji
# Processing Record 178, city: kommunar
# Processing Record 179, city: ladario
# Processing Record 180, city: nanakuli
# Processing Record 181, city: geraldton
# Processing Record 182, city: luba
# Processing Record 183, city: magadi
# Processing Record 184, city: namibe
# Processing Record 185, city: dakar
# Processing Record 186, city: dzhusaly
# Unable to process Record 186, city: dzhusaly not found. Skipping...
# Processing Record 187, city: lucknow
# Processing Record 188, city: lavrentiya
# Processing Record 189, city: sumbawa
# Unable to process Record 189, city: sumbawa not found. Skipping...
# Processing Record 190, city: walvis bay
# Processing Record 191, city: dunedin
# Processing Record 192, city: yantal
# Processing Record 193, city: kahului
# Processing Record 194, city: mezen
# Processing Record 195, city: artyk
# Unable to process Record 195, city: artyk not found. Skipping...
# Processing Record 196, city: sorong
# Processing Record 197, city: chicama
# Processing Record 198, city: curup
# Processing Record 199, city: sumbe
# Processing Record 200, city: atasu
# Processing Record 201, city: north platte
# Processing Record 202, city: talnakh
# Processing Record 203, city: dikson
# Processing Record 204, city: quisqueya
# Processing Record 205, city: salalah
# Processing Record 206, city: beringovskiy
# Processing Record 207, city: flin flon
# Processing Record 208, city: nicoya
# Processing Record 209, city: presque isle
# Processing Record 210, city: mogadishu
# Processing Record 211, city: mahajanga
# Processing Record 212, city: klaksvik
# Processing Record 213, city: polignano a mare
# Processing Record 214, city: ust-nera
# Processing Record 215, city: sitka
# Processing Record 216, city: bredasdorp
# Processing Record 217, city: svetlaya
# Processing Record 218, city: taree
# Processing Record 219, city: mountain home
# Processing Record 220, city: puerto madryn
# Processing Record 221, city: arlit
# Processing Record 222, city: port hedland
# Processing Record 223, city: coquimbo
# Processing Record 224, city: xining
# Processing Record 225, city: yingcheng
# Processing Record 226, city: rehoboth
# Processing Record 227, city: faanui
# Processing Record 228, city: sentyabrskiy
# Unable to process Record 228, city: sentyabrskiy not found. Skipping...
# Processing Record 229, city: westport
# Processing Record 230, city: saint anthony
# Processing Record 231, city: awjilah
# Processing Record 232, city: mercedes
# Processing Record 233, city: berlevag
# Processing Record 234, city: port elizabeth
# Processing Record 235, city: kamina
# Processing Record 236, city: kruisfontein
# Processing Record 237, city: shimoda
# Processing Record 238, city: manta
# Processing Record 239, city: lichuan
# Processing Record 240, city: linqiong
# Processing Record 241, city: timra
# Processing Record 242, city: sri aman
# Processing Record 243, city: zyryanka
# Processing Record 244, city: sobolevo
# Processing Record 245, city: altamont
# Processing Record 246, city: ostersund
# Processing Record 247, city: eureka
# Processing Record 248, city: aljezur
# Processing Record 249, city: svetlyy
# Processing Record 250, city: hovd
# Processing Record 251, city: parfenyevo
# Processing Record 252, city: carnarvon
# Processing Record 253, city: russell
# Processing Record 254, city: ekhabi
# Processing Record 255, city: bababe
# Unable to process Record 255, city: bababe not found. Skipping...
# Processing Record 256, city: gasa
# Processing Record 257, city: guerrero negro
# Processing Record 258, city: vardo
# Processing Record 259, city: the valley
# Processing Record 260, city: pevek
# Processing Record 261, city: grand river south east
# Unable to process Record 261, city: grand river south east not found. Skipping...
# Processing Record 262, city: mehamn
# Processing Record 263, city: taltal
# Processing Record 264, city: touros
# Processing Record 265, city: saryshagan
# Unable to process Record 265, city: saryshagan not found. Skipping...
# Processing Record 266, city: attawapiskat
# Unable to process Record 266, city: attawapiskat not found. Skipping...
# Processing Record 267, city: atambua
# Processing Record 268, city: codrington
# Processing Record 269, city: srednekolymsk
# Processing Record 270, city: bairiki
# Processing Record 271, city: almazar
# Processing Record 272, city: prince albert
# Processing Record 273, city: lasa
# Processing Record 274, city: ahumada
# Unable to process Record 274, city: ahumada not found. Skipping...
# Processing Record 275, city: broken hill
# Processing Record 276, city: tungkang
# Unable to process Record 276, city: tungkang not found. Skipping...
# Processing Record 277, city: alice springs
# Processing Record 278, city: acapulco
# Processing Record 279, city: hofn
# Processing Record 280, city: novo aripuana
# Processing Record 281, city: mawlaik
# Processing Record 282, city: rantepao
# Processing Record 283, city: sooke
# Processing Record 284, city: yunjinghong
# Unable to process Record 284, city: yunjinghong not found. Skipping...
# Processing Record 285, city: sao joao da barra
# Processing Record 286, city: mecca
# Processing Record 287, city: hay river
# Processing Record 288, city: broome
# Processing Record 289, city: rabaul
# Processing Record 290, city: yei
# Processing Record 291, city: mattru
# Processing Record 292, city: nemuro
# Processing Record 293, city: odweyne
# Processing Record 294, city: tasiilaq
# Processing Record 295, city: qaanaaq
# Processing Record 296, city: pangkalanbuun
# Processing Record 297, city: longyearbyen
# Processing Record 298, city: samana
# Processing Record 299, city: opuwo
# Processing Record 300, city: lagoa
# Processing Record 301, city: norman wells
# Processing Record 302, city: nome
# Processing Record 303, city: luganville
# Processing Record 304, city: bluefields
# Processing Record 305, city: sorland
# Processing Record 306, city: grants
# Processing Record 307, city: tateyama
# Processing Record 308, city: meulaboh
# Processing Record 309, city: prince rupert
# Processing Record 310, city: sakakah
# Processing Record 311, city: ullapool
# Processing Record 312, city: tucuman
# Processing Record 313, city: hambantota
# Processing Record 314, city: maniitsoq
# Processing Record 315, city: caceres
# Processing Record 316, city: racine
# Processing Record 317, city: bathsheba
# Processing Record 318, city: jais
# Processing Record 319, city: brigantine
# Processing Record 320, city: charlestown
# Processing Record 321, city: emerald
# Processing Record 322, city: padang
# Processing Record 323, city: ashland
# Processing Record 324, city: aquiraz
# Processing Record 325, city: matagami
# Processing Record 326, city: chabahar
# Processing Record 327, city: prieska
# Processing Record 328, city: banda aceh
# Processing Record 329, city: urdzhar
# Unable to process Record 329, city: urdzhar not found. Skipping...
# Processing Record 330, city: tubmanburg
# Processing Record 331, city: khatanga
# Processing Record 332, city: kainantu
# Processing Record 333, city: nouadhibou
# Processing Record 334, city: te anau
# Processing Record 335, city: comodoro rivadavia
# Processing Record 336, city: grants pass
# Processing Record 337, city: enumclaw
# Processing Record 338, city: gravdal
# Processing Record 339, city: katsuura
# Processing Record 340, city: manjacaze
# Processing Record 341, city: nyurba
# Processing Record 342, city: maarianhamina
# Processing Record 343, city: soe
# Processing Record 344, city: teguise
# Processing Record 345, city: auki
# Processing Record 346, city: chumikan
# Processing Record 347, city: atar
# Processing Record 348, city: maracaibo
# Processing Record 349, city: tezu
# Processing Record 350, city: taman
# Processing Record 351, city: mar del plata
# Processing Record 352, city: rudbar
# Processing Record 353, city: kununurra
# Processing Record 354, city: snezhnogorsk
# Processing Record 355, city: havre-saint-pierre
# Processing Record 356, city: goya
# Processing Record 357, city: atlantic city
# Processing Record 358, city: myitkyina
# Processing Record 359, city: hamilton
# Processing Record 360, city: urdoma
# Processing Record 361, city: komsomolskiy
# Processing Record 362, city: dingle
# Processing Record 363, city: afmadu
# Unable to process Record 363, city: afmadu not found. Skipping...
# Processing Record 364, city: coihaique
# Processing Record 365, city: morros
# Processing Record 366, city: canmore
# Processing Record 367, city: tiarei
# Processing Record 368, city: panguna
# Processing Record 369, city: limbang
# Processing Record 370, city: livingstonia
# Processing Record 371, city: krasnoselkup
# Processing Record 372, city: panjab
# Processing Record 373, city: baringo
# Processing Record 374, city: camopi
# Processing Record 375, city: wakkanai
# Processing Record 376, city: san ramon de la nueva oran
# Processing Record 377, city: rocha
# Processing Record 378, city: payakumbuh
# Processing Record 379, city: belaya gora
# Processing Record 380, city: bjornevatn
# Processing Record 381, city: horta
# Processing Record 382, city: bandar-e anzali
# Processing Record 383, city: umzimvubu
# Unable to process Record 383, city: umzimvubu not found. Skipping...
# Processing Record 384, city: lahaina
# Processing Record 385, city: isangel
# Processing Record 386, city: bac lieu
# Processing Record 387, city: cockburn town
# Processing Record 388, city: ko samui
# Processing Record 389, city: richards bay
# Processing Record 390, city: pirovskoye
# Processing Record 391, city: murwillumbah
# Processing Record 392, city: ivanovka
# Processing Record 393, city: huilong
# Processing Record 394, city: ilulissat
# Processing Record 395, city: requena
# Processing Record 396, city: wahran
# Unable to process Record 396, city: wahran not found. Skipping...
# Processing Record 397, city: suzu
# Unable to process Record 397, city: suzu not found. Skipping...
# Processing Record 398, city: olafsvik
# Processing Record 399, city: puerto el triunfo
# Processing Record 400, city: mikkeli
# Processing Record 401, city: trelew
# Processing Record 402, city: bima
# Processing Record 403, city: semey
# Processing Record 404, city: darnah
# Processing Record 405, city: ilinsko-podomskoye
# Unable to process Record 405, city: ilinsko-podomskoye not found. Skipping...
# Processing Record 406, city: newtonmore
# Processing Record 407, city: shahpur
# Processing Record 408, city: udachnyy
# Processing Record 409, city: parabel
# Processing Record 410, city: hami
# Processing Record 411, city: halalo
# Unable to process Record 411, city: halalo not found. Skipping...
# Processing Record 412, city: eyl
# Processing Record 413, city: marsh harbour
# Processing Record 414, city: port shepstone
# Processing Record 415, city: malwan
# Unable to process Record 415, city: malwan not found. Skipping...
# Processing Record 416, city: pozo colorado
# Processing Record 417, city: yirol
# Unable to process Record 417, city: yirol not found. Skipping...
# Processing Record 418, city: aranos
# Processing Record 419, city: bambous virieux
# Processing Record 420, city: reggio di calabria
# Processing Record 421, city: somerset west
# Processing Record 422, city: dauriya
# Processing Record 423, city: ewa beach
# Processing Record 424, city: comarapa
# Processing Record 425, city: riyaq
# Unable to process Record 425, city: riyaq not found. Skipping...
# Processing Record 426, city: korla
# Processing Record 427, city: queimadas
# Processing Record 428, city: pitkyaranta
# Processing Record 429, city: wajir
# Processing Record 430, city: sahrak
# Unable to process Record 430, city: sahrak not found. Skipping...
# Processing Record 431, city: tabas
# Processing Record 432, city: ugra
# Processing Record 433, city: vestmannaeyjar
# Processing Record 434, city: fort saint john
# Unable to process Record 434, city: fort saint john not found. Skipping...
# Processing Record 435, city: barra do garcas
# Processing Record 436, city: ranfurly
# Processing Record 437, city: virginia beach
# Processing Record 438, city: magadan
# Processing Record 439, city: nuevo progreso
# Processing Record 440, city: asau
# Processing Record 441, city: samusu
# Unable to process Record 441, city: samusu not found. Skipping...
# Processing Record 442, city: lorengau
# Processing Record 443, city: galesong
# Processing Record 444, city: general pico
# Processing Record 445, city: umm kaddadah
# Processing Record 446, city: cheuskiny
# Unable to process Record 446, city: cheuskiny not found. Skipping...
# Processing Record 447, city: hobara
# Processing Record 448, city: nyagan
# Processing Record 449, city: rujewa
# Processing Record 450, city: kara-tyube
# Processing Record 451, city: chapais
# Processing Record 452, city: pimenta bueno
# Processing Record 453, city: sevlievo
# Processing Record 454, city: barranca
# Processing Record 455, city: great falls
# Processing Record 456, city: concepcion del oro
# Processing Record 457, city: iralaya
# Processing Record 458, city: abbeville
# Processing Record 459, city: artvin
# Processing Record 460, city: bursol
# Unable to process Record 460, city: bursol not found. Skipping...
# Processing Record 461, city: skjervoy
# Processing Record 462, city: bronnoysund
# Processing Record 463, city: tsihombe
# Unable to process Record 463, city: tsihombe not found. Skipping...
# Processing Record 464, city: orneta
# Processing Record 465, city: bonito
# Processing Record 466, city: seymchan
# Processing Record 467, city: tidore
# Unable to process Record 467, city: tidore not found. Skipping...
# Processing Record 468, city: deputatskiy
# Processing Record 469, city: hobyo
# Processing Record 470, city: birin
# Processing Record 471, city: temuco
# Processing Record 472, city: wattegama
# Processing Record 473, city: suhbaatar
# Processing Record 474, city: lata
# Processing Record 475, city: kardla
# Processing Record 476, city: olinda
# Processing Record 477, city: yamada
# Processing Record 478, city: biak
# Processing Record 479, city: capivari
# Processing Record 480, city: pietrosani
# Processing Record 481, city: bereda
# Processing Record 482, city: honiara
# Processing Record 483, city: pimentel
# Processing Record 484, city: leshukonskoye
# Processing Record 485, city: alta floresta
# Processing Record 486, city: muravlenko
# Processing Record 487, city: esso
# Processing Record 488, city: kysyl-syr
# Processing Record 489, city: bethanien
# Processing Record 490, city: sinnamary
# Processing Record 491, city: nelson bay
# Processing Record 492, city: kemin
# Processing Record 493, city: bushehr
# Processing Record 494, city: coruripe
# Processing Record 495, city: dafeng
# Processing Record 496, city: batemans bay
# Processing Record 497, city: oussouye
# Processing Record 498, city: apache junction
# Processing Record 499, city: huarmey
# Processing Record 500, city: sambava
# Processing Record 501, city: areosa
# Processing Record 502, city: ahmadpur east
# Processing Record 503, city: ukiah
# Processing Record 504, city: pocoes
# Processing Record 505, city: oranjemund
# Processing Record 506, city: mujiayingzi
# Processing Record 507, city: berkakit
# Processing Record 508, city: san carlos de bariloche
# Processing Record 509, city: ajdabiya
# Processing Record 510, city: wum
# Processing Record 511, city: durusu
# Processing Record 512, city: mukhen
# Processing Record 513, city: iowa city
# Processing Record 514, city: neryungri
# Processing Record 515, city: tabiauea
# Unable to process Record 515, city: tabiauea not found. Skipping...
# Processing Record 516, city: anadyr
# Processing Record 517, city: dawlatabad
# Processing Record 518, city: guabito
# Processing Record 519, city: vaitape
# Processing Record 520, city: buluang
# Processing Record 521, city: stawell
# Processing Record 522, city: antalaha
# Processing Record 523, city: fomboni
# Processing Record 524, city: show low
# Processing Record 525, city: sagbayan
# Processing Record 526, city: isla vista
# Processing Record 527, city: miyako
# Processing Record 528, city: muros
# Processing Record 529, city: scottsbluff
# Processing Record 530, city: la libertad
# Processing Record 531, city: cabo rojo
# Processing Record 532, city: whitianga
# Processing Record 533, city: smithers
# Processing Record 534, city: bilibino
# Processing Record 535, city: olga
# Processing Record 536, city: vicuna
# Processing Record 537, city: pandan
# Processing Record 538, city: millville
# Processing Record 539, city: vangaindrano
# Processing Record 540, city: chirilagua
# Processing Record 541, city: mantua
# Processing Record 542, city: ornskoldsvik
# Processing Record 543, city: qaqortoq
# Processing Record 544, city: bulawayo
# Processing Record 545, city: miranda
# Processing Record 546, city: kijang
# Processing Record 547, city: crotone
# Processing Record 548, city: mayo
# Processing Record 549, city: kodino
# Processing Record 550, city: san-pedro
# Processing Record 551, city: livramento
# Processing Record 552, city: birjand
# Processing Record 553, city: bubaque
# Processing Record 554, city: san jeronimo
# Processing Record 555, city: ternate
# Processing Record 556, city: kuche
# Unable to process Record 556, city: kuche not found. Skipping...
# Processing Record 557, city: tessalit
# Processing Record 558, city: washougal
# Processing Record 559, city: nsanje
# Processing Record 560, city: nyaunglebin
# Processing Record 561, city: brahmapuri
# Unable to process Record 561, city: brahmapuri not found. Skipping...
# Processing Record 562, city: rexburg
# Processing Record 563, city: non sang
# Processing Record 564, city: casablanca
# Processing Record 565, city: dubbo
# Processing Record 566, city: kodinsk
# Processing Record 567, city: ostrovnoy
# Processing Record 568, city: harrismith
# Processing Record 569, city: leningradskiy
# Processing Record 570, city: takoradi
# Processing Record 571, city: sterling
# Processing Record 572, city: buchanan
# Processing Record 573, city: maceio
# Processing Record 574, city: mount gambier
# Processing Record 575, city: okhotsk
# Processing Record 576, city: saint-joseph
# Processing Record 577, city: gannan
# Processing Record 578, city: gat
# Processing Record 579, city: bilma
# Processing Record 580, city: santa rosa
# Processing Record 581, city: necochea
# Processing Record 582, city: ukhta
# Processing Record 583, city: mana
# Processing Record 584, city: sokoni
# Processing Record 585, city: tambura
# Processing Record 586, city: padilla
# Processing Record 587, city: george
# Processing Record 588, city: vanderhoof
# Processing Record 589, city: alpena
# Processing Record 590, city: fushan
# Processing Record 591, city: qandahar
# Unable to process Record 591, city: qandahar not found. Skipping...
# Processing Record 592, city: zlobin
# Processing Record 593, city: praia da vitoria
# Processing Record 594, city: ancud
# Processing Record 595, city: benguela
# Processing Record 596, city: deep river
# Processing Record 597, city: eregli
# Processing Record 598, city: ahipara
# Processing Record 599, city: vanimo
# Processing Record 600, city: kieta
# Processing Record 601, city: zhezkazgan
# Processing Record 602, city: pochutla
# Processing Record 603, city: saeby
# Processing Record 604, city: le pradet
# Processing Record 605, city: nishihara
# Processing Record 606, city: maragogi
# Processing Record 607, city: hirado
# Processing Record 608, city: abu jubayhah
# Unable to process Record 608, city: abu jubayhah not found. Skipping...
# Processing Record 609, city: kutum
# Processing Record 610, city: teahupoo
# Processing Record 611, city: greymouth
# Processing Record 612, city: tonantins
# Processing Record 613, city: kloulklubed
# Processing Record 614, city: paradwip
# Unable to process Record 614, city: paradwip not found. Skipping...
# Processing Record 615, city: shambu
# Processing Record 616, city: belmonte
# Processing Record 617, city: umm durman
# Unable to process Record 617, city: umm durman not found. Skipping...
# Processing Record 618, city: laguna
# Processing Record 619, city: gao
# Processing Record 620, city: luau
# Processing Record 621, city: eskasem
# Unable to process Record 621, city: eskasem not found. Skipping...
# Processing Record 622, city: daman
# Processing Record 623, city: brownsville
# Processing Record 624, city: campoverde
# Processing Record 625, city: turukhansk
# Processing Record 626, city: grand centre
# Unable to process Record 626, city: grand centre not found. Skipping...
# Processing Record 627, city: dzerzhinsk
# Processing Record 628, city: jiaojiang
# Processing Record 629, city: husavik
# Processing Record 630, city: pangai
# Processing Record 631, city: bhayavadar
# Processing Record 632, city: alugan
# Processing Record 633, city: xihe
# Processing Record 634, city: san cristobal
# Processing Record 635, city: batagay-alyta
# Processing Record 636, city: potosi
# Processing Record 637, city: suoyarvi
# Processing Record 638, city: vestmanna
# Processing Record 639, city: hervey bay
# Processing Record 640, city: yumen
# Processing Record 641, city: ugoofaaru
# Processing Record 642, city: ambodifototra
# Unable to process Record 642, city: ambodifototra not found. Skipping...
# Processing Record 643, city: nang rong
# Processing Record 644, city: paamiut
# Processing Record 645, city: gashua
# -----End of processing-------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.dropna(inplace=True)
weather_df.to_csv('output_data/cities.csv')
weather_df
# Out:
#            Cities Country          Date  Latitude  Longitude  Temperature (F)  \
# 0            buin      CL  1.601702e+09    -33.73     -70.75           281.62
# 1    constitucion      CL  1.601702e+09    -35.33     -72.42           280.54
# 2       ulladulla      AU  1.601702e+09    -35.35     150.47           301.44
# 3      whitecourt      CA  1.601702e+09     54.15    -115.69           283.15
# 4          barrow      US  1.601702e+09     71.29    -156.79           275.15
# ..            ...     ...           ...       ...        ...              ...
# 639         yumen      CN  1.601702e+09     40.28      97.20           286.43
# 640     ugoofaaru      MV  1.601702e+09      5.67      73.00           301.24
# 642     nang rong      TH  1.601702e+09     14.64     102.79           302.70
# 643       paamiut      GL  1.601702e+09     61.99     -49.67           275.79
# 644        gashua      NG  1.601702e+09     12.87      11.05           300.02
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0            80.0            11.0              2.60
# 1            75.0             3.0              4.15
# 2            23.0             0.0              6.20
# 3            68.0            20.0              0.74
# 4            95.0            90.0              8.70
# ..            ...             ...               ...
# 639          29.0             0.0              7.91
# 640          72.0            95.0              5.52
# 642          83.0            75.0              1.50
# 643          88.0           100.0              3.40
# 644          60.0            47.0              3.90
#
# [592 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#                Date    Latitude   Longitude  Temperature (F)  Humidity (%)  \
# count  5.920000e+02  592.000000  592.000000       592.000000    592.000000
# mean   1.601702e+09   18.929561   19.331757       290.368953     71.827703
# std    1.274467e+02   34.166154   92.619963         9.586911     20.535159
# min    1.601701e+09  -54.800000 -175.200000       266.230000      5.000000
# 25%    1.601702e+09   -9.815000  -64.860000       282.497500     63.000000
# 50%    1.601702e+09   21.445000   25.340000       291.280000     76.000000
# 75%    1.601702e+09   46.457500  102.272500       298.205000     87.000000
# max    1.601702e+09   78.220000  179.320000       312.150000    100.000000
#
#        Cloudiness (%)  Wind Speed (mph)
# count      592.000000        592.000000
# mean        50.258446          3.592280
# std         38.759518          2.444108
# min          0.000000          0.110000
# 25%          6.000000          1.627500
# 50%         50.000000          2.960000
# 75%         90.000000          5.020000
# max        100.000000         11.900000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# No Cities with humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Temperature (F)'], facecolors='red', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Temperature.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: Temperatures generally increase as the cities get closer to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Humidity (%)'], facecolors='blue', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Humidity')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Humidity.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: The charts do not demonstrate correlation between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness (%)'], facecolors='yellow', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Cloudiness.png')

# Show Plot
plt.show()

# %% [markdown]
# OBSERVATION: The charts do not demonstrate correlation between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot 
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed (mph)'], facecolors='green', marker='o', edgecolor='black')

# Define Graph Attributes
plt.title('City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

# Save Figure
plt.savefig('output_data/City_Latitude_vs_Wind Speed.png')

# Show Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# OBSERVATION: The wind speeds are higher further from the equator.

# %% [markdown]
# ## Linear Regression

# %%
#get data for northern hemisphere
north_df = weather_df.loc[weather_df['Latitude'] > 0]
south_df = weather_df.loc[weather_df['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Temperature (F)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='red', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"b-")


# Define Graph Attributes
plt.annotate(line_eq,(0,270),fontsize=15,color='blue')
plt.title('Northern Hemisphere City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: -0.8529183618553597

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Temperature (F)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='red', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"b-")


# Define Graph Attributes
plt.annotate(line_eq,(-30,275),fontsize=15,color='blue')
plt.title('Southern Hemisphere City Latitude vs. Temperature')
plt.ylabel('Temperature (°F)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.6349144398299843

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Humidity (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='blue', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(45,10),fontsize=15,color='red')
plt.title('Northern Hemisphere City Latitude vs. Humidity')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.1709615122452965

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Humidity (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='blue', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(-55,5),fontsize=15,color='red')
plt.title('Southern Hemisphere City Latitude vs. Humidity')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.10484840730855077

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Cloudiness (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='yellow', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"g-")


# Define Graph Attributes
plt.annotate(line_eq,(10,60),fontsize=15,color='green')
plt.title('Northern Hemisphere City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.16319180150840853

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Cloudiness (%)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='yellow', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"g-")


# Define Graph Attributes
plt.annotate(line_eq,(0,10),fontsize=15,color='green')
plt.title('Southern Hemisphere City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.05423007472245309

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = north_df['Latitude']
y_values = north_df['Wind Speed (mph)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='green', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(10,10),fontsize=15,color='red')
plt.title('Northern Hemisphere City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: 0.19077148706943337

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#define x and y values
x_values = south_df['Latitude']
y_values = south_df['Wind Speed (mph)']

# calculate the linear regression equation and line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot
plt.scatter(x_values, y_values, facecolors='green', marker='o', edgecolor='black')
plt.plot(x_values,regress_values,"r-")


# Define Graph Attributes
plt.annotate(line_eq,(-55,11),fontsize=15,color='red')
plt.title('Southern Hemisphere City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#print r value
print(f"The r value is: {rvalue}")

# Show Plot
plt.show()
# Out:
# The r value is: -0.12714649804600683
